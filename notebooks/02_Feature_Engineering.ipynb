# %% [markdown]
# # Feature Engineering
#
# En esta etapa se construyen nuevas variables que faciliten la identificación del riesgo crediticio.

# %%
from src.data import load_data

from src.feature_engineering import create_customer_profile

df = load_data("german_credit.csv")

df = create_customer_profile(df)

df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from src.data_loader import load_data
#       2
#       3 from src.feature_engineering import create_customer_profile
#       4
#
# ModuleNotFoundError: No module named 'src'

# %%
df[

[
"customer_age",
"age_group",
"loan_amount",
"loan_category"

]

].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df["age_group"].value_counts()
#
# NameError: name 'df' is not defined

# %%
df["age_group"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df["loan_size"].value_counts()
#
# NameError: name 'df' is not defined

# %%
df["loan_category"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df["loan_category"].value_counts()
#
# NameError: name 'df' is not defined
